# %%
import os
import glob
import xml.etree.ElementTree as ET

from xml.etree.ElementTree import ParseError  # 추가

# ---------- 1. 설정 ----------
XML_ROOT = r"label"  # 네 XML 폴더 경로
OUT_OPEN_CLOSE = r"./labels_openclose"
OUT_FULL_EMPTY = r"./labels_fullempty"

OPEN_CLOSE_MAP = {
    "open_empty": 0,
    "open_full": 0,
    "close_full": 1,
    "close_empty": 1,
}

FULL_EMPTY_MAP = {
    "open_empty": 0,
    "close_empty": 0,
    "open_full": 1,
    "close_full": 1,
}

def voc_to_yolo_bbox(size, box):
    w_img, h_img = size
    xmin, ymin, xmax, ymax = box

    x_center = (xmin + xmax) / 2.0 / w_img
    y_center = (ymin + ymax) / 2.0 / h_img
    bw = (xmax - xmin) / w_img
    bh = (ymax - ymin) / h_img

    return x_center, y_center, bw, bh


def convert_single_xml_2x2(xml_path, out_dir_openclose, out_dir_fullempty):
    # ✅ 여기서 try/except로 깨진 XML 잡기
    try:
        tree = ET.parse(xml_path)
    except ParseError as e:
        print(f"[ERROR] XML ParseError in '{xml_path}': {e}")
        # 이 파일은 건너뜀
        return

    root = tree.getroot()

    size = root.find("size")
    w_img = int(size.find("width").text)
    h_img = int(size.find("height").text)

    base = os.path.splitext(os.path.basename(xml_path))[0]

    out_txt_openclose = os.path.join(out_dir_openclose, base + ".txt")
    out_txt_fullempty = os.path.join(out_dir_fullempty, base + ".txt")

    lines_openclose = []
    lines_fullempty = []

    for obj in root.findall("object"):
        name = obj.find("name").text.strip()

        if name not in OPEN_CLOSE_MAP or name not in FULL_EMPTY_MAP:
            print(f"[WARN] Unknown class '{name}' in {xml_path}, skip this object.")
            continue

        cls_openclose = OPEN_CLOSE_MAP[name]
        cls_fullempty = FULL_EMPTY_MAP[name]

        bnd = obj.find("bndbox")
        xmin = float(bnd.find("xmin").text)
        ymin = float(bnd.find("ymin").text)
        xmax = float(bnd.find("xmax").text)
        ymax = float(bnd.find("ymax").text)

        x_c, y_c, bw, bh = voc_to_yolo_bbox((w_img, h_img), (xmin, ymin, xmax, ymax))

        lines_openclose.append(f"{cls_openclose} {x_c:.6f} {y_c:.6f} {bw:.6f} {bh:.6f}")
        lines_fullempty.append(f"{cls_fullempty} {x_c:.6f} {y_c:.6f} {bw:.6f} {bh:.6f}")

    os.makedirs(out_dir_openclose, exist_ok=True)
    os.makedirs(out_dir_fullempty, exist_ok=True)

    with open(out_txt_openclose, "w", encoding="utf-8") as f:
        f.write("\n".join(lines_openclose))

    with open(out_txt_fullempty, "w", encoding="utf-8") as f:
        f.write("\n".join(lines_fullempty))

    print(f"[INFO] {xml_path} ->")
    print(f"       {out_txt_openclose} (open/close)")
    print(f"       {out_txt_fullempty} (full/empty)")


def convert_all_xml_in_root(root_dir, out_dir_openclose, out_dir_fullempty):
    pattern = os.path.join(root_dir, "**", "*.xml")
    xml_paths = glob.glob(pattern, recursive=True)

    print(f"[INFO] Found {len(xml_paths)} xml files under {root_dir}")

    for xml_path in xml_paths:
        convert_single_xml_2x2(xml_path, out_dir_openclose, out_dir_fullempty)


if __name__ == "__main__":
    convert_all_xml_in_root(XML_ROOT, OUT_OPEN_CLOSE, OUT_FULL_EMPTY)
# Out:
# [INFO] Found 511 xml files under label
# [INFO] label\photo_normal_002.xml ->
#        ./labels_openclose\photo_normal_002.txt (open/close)
#        ./labels_fullempty\photo_normal_002.txt (full/empty)
# [INFO] label\photo_normal_004.xml ->
#        ./labels_openclose\photo_normal_004.txt (open/close)
#        ./labels_fullempty\photo_normal_004.txt (full/empty)
# [INFO] label\photo_normal_005.xml ->
#        ./labels_openclose\photo_normal_005.txt (open/close)
#        ./labels_fullempty\photo_normal_005.txt (full/empty)
# [INFO] label\photo_normal_006.xml ->
#        ./labels_openclose\photo_normal_006.txt (open/close)
#        ./labels_fullempty\photo_normal_006.txt (full/empty)
# [INFO] label\photo_normal_007.xml ->
#        ./labels_openclose\photo_normal_007.txt (open/close)
#        ./labels_fullempty\photo_normal_007.txt (full/empty)
# [INFO] label\photo_normal_008.xml ->
#        ./labels_openclose\photo_normal_008.txt (open/close)
#        ./labels_fullempty\photo_normal_008.txt (full/empty)
# [INFO] label\photo_normal_009.xml ->
#        ./labels_openclose\photo_normal_009.txt (open/close)
#        ./labels_fullempty\photo_normal_009.txt (full/empty)
# [INFO] label\photo_normal_010.xml ->
#        ./labels_openclose\photo_normal_010.txt (open/close)
#        ./labels_fullempty\photo_normal_010.txt (full/empty)
# [INFO] label\photo_normal_012.xml ->
#        ./labels_openclose\photo_normal_012.txt (open/close)
#        ./labels_fullempty\photo_normal_012.txt (full/empty)
# [INFO] label\photo_normal_013.xml ->
#        ./labels_openclose\photo_normal_013.txt (open/close)
#        ./labels_fullempty\photo_normal_013.txt (full/empty)
# [INFO] label\photo_normal_014.xml ->
#        ./labels_openclose\photo_normal_014.txt (open/close)
#        ./labels_fullempty\photo_normal_014.txt (full/empty)
# [INFO] label\photo_normal_015.xml ->
#        ./labels_openclose\photo_normal_015.txt (open/close)
#        ./labels_fullempty\photo_normal_015.txt (full/empty)
# [INFO] label\photo_normal_016.xml ->
#        ./labels_openclose\photo_normal_016.txt (open/close)
#        ./labels_fullempty\photo_normal_016.txt (full/empty)
# [INFO] label\photo_normal_017.xml ->
#        ./labels_openclose\photo_normal_017.txt (open/close)
#        ./labels_fullempty\photo_normal_017.txt (full/empty)
# [INFO] label\photo_normal_018.xml ->
#        ./labels_openclose\photo_normal_018.txt (open/close)
#        ./labels_fullempty\photo_normal_018.txt (full/empty)
# [INFO] label\photo_normal_019.xml ->
#        ./labels_openclose\photo_normal_019.txt (open/close)
#        ./labels_fullempty\photo_normal_019.txt (full/empty)
# [INFO] label\photo_normal_020.xml ->
#        ./labels_openclose\photo_normal_020.txt (open/close)
#        ./labels_fullempty\photo_normal_020.txt (full/empty)
# [INFO] label\photo_normal_021.xml ->
#        ./labels_openclose\photo_normal_021.txt (open/close)
#        ./labels_fullempty\photo_normal_021.txt (full/empty)
# [INFO] label\photo_normal_022.xml ->
#        ./labels_openclose\photo_normal_022.txt (open/close)
#        ./labels_fullempty\photo_normal_022.txt (full/empty)
# [INFO] label\photo_normal_023.xml ->
#        ./labels_openclose\photo_normal_023.txt (open/close)
#        ./labels_fullempty\photo_normal_023.txt (full/empty)
# [INFO] label\photo_normal_024.xml ->
#        ./labels_openclose\photo_normal_024.txt (open/close)
#        ./labels_fullempty\photo_normal_024.txt (full/empty)
# [INFO] label\photo_normal_025.xml ->
#        ./labels_openclose\photo_normal_025.txt (open/close)
#        ./labels_fullempty\photo_normal_025.txt (full/empty)
# [INFO] label\photo_normal_026.xml ->
#        ./labels_openclose\photo_normal_026.txt (open/close)
#        ./labels_fullempty\photo_normal_026.txt (full/empty)
# [INFO] label\photo_normal_027.xml ->
#        ./labels_openclose\photo_normal_027.txt (open/close)
#        ./labels_fullempty\photo_normal_027.txt (full/empty)
# [INFO] label\photo_normal_028.xml ->
#        ./labels_openclose\photo_normal_028.txt (open/close)
#        ./labels_fullempty\photo_normal_028.txt (full/empty)
# [INFO] label\photo_normal_029.xml ->
#        ./labels_openclose\photo_normal_029.txt (open/close)
#        ./labels_fullempty\photo_normal_029.txt (full/empty)
# [INFO] label\photo_normal_030.xml ->
#        ./labels_openclose\photo_normal_030.txt (open/close)
#        ./labels_fullempty\photo_normal_030.txt (full/empty)
# [INFO] label\photo_normal_031.xml ->
#        ./labels_openclose\photo_normal_031.txt (open/close)
#        ./labels_fullempty\photo_normal_031.txt (full/empty)
# [INFO] label\photo_normal_032.xml ->
#        ./labels_openclose\photo_normal_032.txt (open/close)
#        ./labels_fullempty\photo_normal_032.txt (full/empty)
# [INFO] label\photo_normal_033.xml ->
#        ./labels_openclose\photo_normal_033.txt (open/close)
#        ./labels_fullempty\photo_normal_033.txt (full/empty)
# [INFO] label\photo_normal_034.xml ->
#        ./labels_openclose\photo_normal_034.txt (open/close)
#        ./labels_fullempty\photo_normal_034.txt (full/empty)
# [INFO] label\photo_normal_035.xml ->
#        ./labels_openclose\photo_normal_035.txt (open/close)
#        ./labels_fullempty\photo_normal_035.txt (full/empty)
# [INFO] label\photo_normal_036.xml ->
#        ./labels_openclose\photo_normal_036.txt (open/close)
#        ./labels_fullempty\photo_normal_036.txt (full/empty)
# [INFO] label\photo_normal_037.xml ->
#        ./labels_openclose\photo_normal_037.txt (open/close)
#        ./labels_fullempty\photo_normal_037.txt (full/empty)
# [INFO] label\photo_normal_038.xml ->
#        ./labels_openclose\photo_normal_038.txt (open/close)
#        ./labels_fullempty\photo_normal_038.txt (full/empty)
# [INFO] label\photo_normal_039.xml ->
#        ./labels_openclose\photo_normal_039.txt (open/close)
#        ./labels_fullempty\photo_normal_039.txt (full/empty)
# [INFO] label\photo_normal_040.xml ->
#        ./labels_openclose\photo_normal_040.txt (open/close)
#        ./labels_fullempty\photo_normal_040.txt (full/empty)
# [INFO] label\photo_normal_041.xml ->
#        ./labels_openclose\photo_normal_041.txt (open/close)
#        ./labels_fullempty\photo_normal_041.txt (full/empty)
# [INFO] label\photo_normal_042.xml ->
#        ./labels_openclose\photo_normal_042.txt (open/close)
#        ./labels_fullempty\photo_normal_042.txt (full/empty)
# [INFO] label\photo_normal_043.xml ->
#        ./labels_openclose\photo_normal_043.txt (open/close)
#        ./labels_fullempty\photo_normal_043.txt (full/empty)
# [INFO] label\photo_normal_044.xml ->
#        ./labels_openclose\photo_normal_044.txt (open/close)
#        ./labels_fullempty\photo_normal_044.txt (full/empty)
# [INFO] label\photo_normal_045.xml ->
#        ./labels_openclose\photo_normal_045.txt (open/close)
#        ./labels_fullempty\photo_normal_045.txt (full/empty)
# [INFO] label\photo_normal_046.xml ->
#        ./labels_openclose\photo_normal_046.txt (open/close)
#        ./labels_fullempty\photo_normal_046.txt (full/empty)
# [INFO] label\photo_normal_047.xml ->
#        ./labels_openclose\photo_normal_047.txt (open/close)
#        ./labels_fullempty\photo_normal_047.txt (full/empty)
# [INFO] label\photo_normal_048.xml ->
#        ./labels_openclose\photo_normal_048.txt (open/close)
#        ./labels_fullempty\photo_normal_048.txt (full/empty)
# [INFO] label\photo_normal_049.xml ->
#        ./labels_openclose\photo_normal_049.txt (open/close)
#        ./labels_fullempty\photo_normal_049.txt (full/empty)
# [INFO] label\photo_normal_050.xml ->
#        ./labels_openclose\photo_normal_050.txt (open/close)
#        ./labels_fullempty\photo_normal_050.txt (full/empty)
# [INFO] label\photo_normal_051.xml ->
#        ./labels_openclose\photo_normal_051.txt (open/close)
#        ./labels_fullempty\photo_normal_051.txt (full/empty)
# [INFO] label\photo_normal_052.xml ->
#        ./labels_openclose\photo_normal_052.txt (open/close)
#        ./labels_fullempty\photo_normal_052.txt (full/empty)
# [INFO] label\photo_normal_053.xml ->
#        ./labels_openclose\photo_normal_053.txt (open/close)
#        ./labels_fullempty\photo_normal_053.txt (full/empty)
# [INFO] label\photo_normal_054.xml ->
#        ./labels_openclose\photo_normal_054.txt (open/close)
#        ./labels_fullempty\photo_normal_054.txt (full/empty)
# [INFO] label\photo_normal_055.xml ->
#        ./labels_openclose\photo_normal_055.txt (open/close)
#        ./labels_fullempty\photo_normal_055.txt (full/empty)
# [INFO] label\photo_normal_056.xml ->
#        ./labels_openclose\photo_normal_056.txt (open/close)
#        ./labels_fullempty\photo_normal_056.txt (full/empty)
# [INFO] label\photo_normal_057.xml ->
#        ./labels_openclose\photo_normal_057.txt (open/close)
#        ./labels_fullempty\photo_normal_057.txt (full/empty)
# [INFO] label\photo_normal_058.xml ->
#        ./labels_openclose\photo_normal_058.txt (open/close)
#        ./labels_fullempty\photo_normal_058.txt (full/empty)
# [INFO] label\photo_normal_059.xml ->
#        ./labels_openclose\photo_normal_059.txt (open/close)
#        ./labels_fullempty\photo_normal_059.txt (full/empty)
# [INFO] label\photo_normal_060.xml ->
#        ./labels_openclose\photo_normal_060.txt (open/close)
#        ./labels_fullempty\photo_normal_060.txt (full/empty)
# [INFO] label\photo_normal_061.xml ->
#        ./labels_openclose\photo_normal_061.txt (open/close)
#        ./labels_fullempty\photo_normal_061.txt (full/empty)
# [INFO] label\photo_normal_062.xml ->
#        ./labels_openclose\photo_normal_062.txt (open/close)
#        ./labels_fullempty\photo_normal_062.txt (full/empty)
# [INFO] label\photo_normal_063.xml ->
#        ./labels_openclose\photo_normal_063.txt (open/close)
#        ./labels_fullempty\photo_normal_063.txt (full/empty)
# [INFO] label\photo_normal_064.xml ->
#        ./labels_openclose\photo_normal_064.txt (open/close)
#        ./labels_fullempty\photo_normal_064.txt (full/empty)
# [INFO] label\photo_normal_065.xml ->
#        ./labels_openclose\photo_normal_065.txt (open/close)
#        ./labels_fullempty\photo_normal_065.txt (full/empty)
# [INFO] label\photo_normal_066.xml ->
#        ./labels_openclose\photo_normal_066.txt (open/close)
#        ./labels_fullempty\photo_normal_066.txt (full/empty)
# [INFO] label\photo_normal_067.xml ->
#        ./labels_openclose\photo_normal_067.txt (open/close)
#        ./labels_fullempty\photo_normal_067.txt (full/empty)
# [INFO] label\photo_normal_068.xml ->
#        ./labels_openclose\photo_normal_068.txt (open/close)
#        ./labels_fullempty\photo_normal_068.txt (full/empty)
# [INFO] label\photo_normal_069.xml ->
#        ./labels_openclose\photo_normal_069.txt (open/close)
#        ./labels_fullempty\photo_normal_069.txt (full/empty)
# [INFO] label\photo_normal_070.xml ->
#        ./labels_openclose\photo_normal_070.txt (open/close)
#        ./labels_fullempty\photo_normal_070.txt (full/empty)
# [INFO] label\photo_normal_071.xml ->
#        ./labels_openclose\photo_normal_071.txt (open/close)
#        ./labels_fullempty\photo_normal_071.txt (full/empty)
# [INFO] label\photo_normal_072.xml ->
#        ./labels_openclose\photo_normal_072.txt (open/close)
#        ./labels_fullempty\photo_normal_072.txt (full/empty)
# [INFO] label\photo_normal_073.xml ->
#        ./labels_openclose\photo_normal_073.txt (open/close)
#        ./labels_fullempty\photo_normal_073.txt (full/empty)
# [INFO] label\photo_normal_074.xml ->
#        ./labels_openclose\photo_normal_074.txt (open/close)
#        ./labels_fullempty\photo_normal_074.txt (full/empty)
# [INFO] label\photo_normal_075.xml ->
#        ./labels_openclose\photo_normal_075.txt (open/close)
#        ./labels_fullempty\photo_normal_075.txt (full/empty)
# [INFO] label\photo_normal_076.xml ->
#        ./labels_openclose\photo_normal_076.txt (open/close)
#        ./labels_fullempty\photo_normal_076.txt (full/empty)
# [INFO] label\photo_normal_077.xml ->
#        ./labels_openclose\photo_normal_077.txt (open/close)
#        ./labels_fullempty\photo_normal_077.txt (full/empty)
# [INFO] label\photo_normal_078.xml ->
#        ./labels_openclose\photo_normal_078.txt (open/close)
#        ./labels_fullempty\photo_normal_078.txt (full/empty)
# [INFO] label\photo_normal_079.xml ->
#        ./labels_openclose\photo_normal_079.txt (open/close)
#        ./labels_fullempty\photo_normal_079.txt (full/empty)
# [INFO] label\photo_normal_080.xml ->
#        ./labels_openclose\photo_normal_080.txt (open/close)
#        ./labels_fullempty\photo_normal_080.txt (full/empty)
# [INFO] label\photo_normal_081.xml ->
#        ./labels_openclose\photo_normal_081.txt (open/close)
#        ./labels_fullempty\photo_normal_081.txt (full/empty)
# [INFO] label\photo_normal_082.xml ->
#        ./labels_openclose\photo_normal_082.txt (open/close)
#        ./labels_fullempty\photo_normal_082.txt (full/empty)
# [INFO] label\photo_normal_083.xml ->
#        ./labels_openclose\photo_normal_083.txt (open/close)
#        ./labels_fullempty\photo_normal_083.txt (full/empty)
# [INFO] label\photo_normal_085.xml ->
#        ./labels_openclose\photo_normal_085.txt (open/close)
#        ./labels_fullempty\photo_normal_085.txt (full/empty)
# [INFO] label\photo_normal_086.xml ->
#        ./labels_openclose\photo_normal_086.txt (open/close)
#        ./labels_fullempty\photo_normal_086.txt (full/empty)
# [INFO] label\photo_normal_087.xml ->
#        ./labels_openclose\photo_normal_087.txt (open/close)
#        ./labels_fullempty\photo_normal_087.txt (full/empty)
# [INFO] label\photo_normal_088.xml ->
#        ./labels_openclose\photo_normal_088.txt (open/close)
#        ./labels_fullempty\photo_normal_088.txt (full/empty)
# [INFO] label\photo_normal_089.xml ->
#        ./labels_openclose\photo_normal_089.txt (open/close)
#        ./labels_fullempty\photo_normal_089.txt (full/empty)
# [INFO] label\photo_normal_090.xml ->
#        ./labels_openclose\photo_normal_090.txt (open/close)
#        ./labels_fullempty\photo_normal_090.txt (full/empty)
# [INFO] label\photo_normal_091.xml ->
#        ./labels_openclose\photo_normal_091.txt (open/close)
#        ./labels_fullempty\photo_normal_091.txt (full/empty)
# [INFO] label\photo_normal_092.xml ->
#        ./labels_openclose\photo_normal_092.txt (open/close)
#        ./labels_fullempty\photo_normal_092.txt (full/empty)
# [INFO] label\photo_normal_093.xml ->
#        ./labels_openclose\photo_normal_093.txt (open/close)
#        ./labels_fullempty\photo_normal_093.txt (full/empty)
# [INFO] label\photo_normal_094.xml ->
#        ./labels_openclose\photo_normal_094.txt (open/close)
#        ./labels_fullempty\photo_normal_094.txt (full/empty)
# [INFO] label\photo_normal_095.xml ->
#        ./labels_openclose\photo_normal_095.txt (open/close)
#        ./labels_fullempty\photo_normal_095.txt (full/empty)
# [INFO] label\photo_normal_096.xml ->
#        ./labels_openclose\photo_normal_096.txt (open/close)
#        ./labels_fullempty\photo_normal_096.txt (full/empty)
# [INFO] label\photo_normal_097.xml ->
#        ./labels_openclose\photo_normal_097.txt (open/close)
#        ./labels_fullempty\photo_normal_097.txt (full/empty)
# [INFO] label\photo_normal_098.xml ->
#        ./labels_openclose\photo_normal_098.txt (open/close)
#        ./labels_fullempty\photo_normal_098.txt (full/empty)
# [INFO] label\photo_normal_099.xml ->
#        ./labels_openclose\photo_normal_099.txt (open/close)
#        ./labels_fullempty\photo_normal_099.txt (full/empty)
# [INFO] label\photo_normal_100.xml ->
#        ./labels_openclose\photo_normal_100.txt (open/close)
#        ./labels_fullempty\photo_normal_100.txt (full/empty)
# [INFO] label\photo_normal_101.xml ->
#        ./labels_openclose\photo_normal_101.txt (open/close)
#        ./labels_fullempty\photo_normal_101.txt (full/empty)
# [INFO] label\photo_normal_102.xml ->
#        ./labels_openclose\photo_normal_102.txt (open/close)
#        ./labels_fullempty\photo_normal_102.txt (full/empty)
# [INFO] label\photo_normal_103.xml ->
#        ./labels_openclose\photo_normal_103.txt (open/close)
#        ./labels_fullempty\photo_normal_103.txt (full/empty)
# [INFO] label\photo_normal_104.xml ->
#        ./labels_openclose\photo_normal_104.txt (open/close)
#        ./labels_fullempty\photo_normal_104.txt (full/empty)
# [INFO] label\photo_normal_105.xml ->
#        ./labels_openclose\photo_normal_105.txt (open/close)
#        ./labels_fullempty\photo_normal_105.txt (full/empty)
# [INFO] label\photo_normal_106.xml ->
#        ./labels_openclose\photo_normal_106.txt (open/close)
#        ./labels_fullempty\photo_normal_106.txt (full/empty)
# [INFO] label\photo_normal_107.xml ->
#        ./labels_openclose\photo_normal_107.txt (open/close)
#        ./labels_fullempty\photo_normal_107.txt (full/empty)
# [INFO] label\photo_normal_108.xml ->
#        ./labels_openclose\photo_normal_108.txt (open/close)
#        ./labels_fullempty\photo_normal_108.txt (full/empty)
# [INFO] label\photo_normal_109.xml ->
#        ./labels_openclose\photo_normal_109.txt (open/close)
#        ./labels_fullempty\photo_normal_109.txt (full/empty)
# [INFO] label\photo_normal_110.xml ->
#        ./labels_openclose\photo_normal_110.txt (open/close)
#        ./labels_fullempty\photo_normal_110.txt (full/empty)
# [INFO] label\photo_normal_111.xml ->
#        ./labels_openclose\photo_normal_111.txt (open/close)
#        ./labels_fullempty\photo_normal_111.txt (full/empty)
# [INFO] label\photo_normal_112.xml ->
#        ./labels_openclose\photo_normal_112.txt (open/close)
#        ./labels_fullempty\photo_normal_112.txt (full/empty)
# [INFO] label\photo_normal_113.xml ->
#        ./labels_openclose\photo_normal_113.txt (open/close)
#        ./labels_fullempty\photo_normal_113.txt (full/empty)
# [INFO] label\photo_normal_114.xml ->
#        ./labels_openclose\photo_normal_114.txt (open/close)
#        ./labels_fullempty\photo_normal_114.txt (full/empty)
# [INFO] label\photo_normal_115.xml ->
#        ./labels_openclose\photo_normal_115.txt (open/close)
#        ./labels_fullempty\photo_normal_115.txt (full/empty)
# [INFO] label\photo_normal_116.xml ->
#        ./labels_openclose\photo_normal_116.txt (open/close)
#        ./labels_fullempty\photo_normal_116.txt (full/empty)
# [INFO] label\photo_normal_117.xml ->
#        ./labels_openclose\photo_normal_117.txt (open/close)
#        ./labels_fullempty\photo_normal_117.txt (full/empty)
# [INFO] label\photo_normal_118.xml ->
#        ./labels_openclose\photo_normal_118.txt (open/close)
#        ./labels_fullempty\photo_normal_118.txt (full/empty)
# [INFO] label\photo_normal_119.xml ->
#        ./labels_openclose\photo_normal_119.txt (open/close)
#        ./labels_fullempty\photo_normal_119.txt (full/empty)
# [INFO] label\photo_normal_120.xml ->
#        ./labels_openclose\photo_normal_120.txt (open/close)
#        ./labels_fullempty\photo_normal_120.txt (full/empty)
# [INFO] label\photo_normal_121.xml ->
#        ./labels_openclose\photo_normal_121.txt (open/close)
#        ./labels_fullempty\photo_normal_121.txt (full/empty)
# [INFO] label\photo_normal_122.xml ->
#        ./labels_openclose\photo_normal_122.txt (open/close)
#        ./labels_fullempty\photo_normal_122.txt (full/empty)
# [INFO] label\photo_normal_123.xml ->
#        ./labels_openclose\photo_normal_123.txt (open/close)
#        ./labels_fullempty\photo_normal_123.txt (full/empty)
# [INFO] label\photo_normal_124.xml ->
#        ./labels_openclose\photo_normal_124.txt (open/close)
#        ./labels_fullempty\photo_normal_124.txt (full/empty)
# [INFO] label\photo_normal_125.xml ->
#        ./labels_openclose\photo_normal_125.txt (open/close)
#        ./labels_fullempty\photo_normal_125.txt (full/empty)
# [INFO] label\photo_normal_126.xml ->
#        ./labels_openclose\photo_normal_126.txt (open/close)
#        ./labels_fullempty\photo_normal_126.txt (full/empty)
# [INFO] label\photo_normal_127.xml ->
#        ./labels_openclose\photo_normal_127.txt (open/close)
#        ./labels_fullempty\photo_normal_127.txt (full/empty)
# [INFO] label\photo_normal_128.xml ->
#        ./labels_openclose\photo_normal_128.txt (open/close)
#        ./labels_fullempty\photo_normal_128.txt (full/empty)
# [INFO] label\photo_normal_129.xml ->
#        ./labels_openclose\photo_normal_129.txt (open/close)
#        ./labels_fullempty\photo_normal_129.txt (full/empty)
# [INFO] label\photo_normal_130.xml ->
#        ./labels_openclose\photo_normal_130.txt (open/close)
#        ./labels_fullempty\photo_normal_130.txt (full/empty)
# [INFO] label\photo_normal_131.xml ->
#        ./labels_openclose\photo_normal_131.txt (open/close)
#        ./labels_fullempty\photo_normal_131.txt (full/empty)
# [INFO] label\photo_normal_132.xml ->
#        ./labels_openclose\photo_normal_132.txt (open/close)
#        ./labels_fullempty\photo_normal_132.txt (full/empty)
# [INFO] label\photo_normal_133.xml ->
#        ./labels_openclose\photo_normal_133.txt (open/close)
#        ./labels_fullempty\photo_normal_133.txt (full/empty)
# [INFO] label\photo_normal_134.xml ->
#        ./labels_openclose\photo_normal_134.txt (open/close)
#        ./labels_fullempty\photo_normal_134.txt (full/empty)
# [INFO] label\photo_normal_135.xml ->
#        ./labels_openclose\photo_normal_135.txt (open/close)
#        ./labels_fullempty\photo_normal_135.txt (full/empty)
# [INFO] label\photo_normal_136.xml ->
#        ./labels_openclose\photo_normal_136.txt (open/close)
#        ./labels_fullempty\photo_normal_136.txt (full/empty)
# [INFO] label\photo_normal_137.xml ->
#        ./labels_openclose\photo_normal_137.txt (open/close)
#        ./labels_fullempty\photo_normal_137.txt (full/empty)
# [INFO] label\photo_normal_138.xml ->
#        ./labels_openclose\photo_normal_138.txt (open/close)
#        ./labels_fullempty\photo_normal_138.txt (full/empty)
# [INFO] label\photo_normal_139.xml ->
#        ./labels_openclose\photo_normal_139.txt (open/close)
#        ./labels_fullempty\photo_normal_139.txt (full/empty)
# [INFO] label\photo_normal_140.xml ->
#        ./labels_openclose\photo_normal_140.txt (open/close)
#        ./labels_fullempty\photo_normal_140.txt (full/empty)
# [INFO] label\photo_normal_141.xml ->
#        ./labels_openclose\photo_normal_141.txt (open/close)
#        ./labels_fullempty\photo_normal_141.txt (full/empty)
# [INFO] label\photo_normal_142.xml ->
#        ./labels_openclose\photo_normal_142.txt (open/close)
#        ./labels_fullempty\photo_normal_142.txt (full/empty)
# [INFO] label\photo_normal_143.xml ->
#        ./labels_openclose\photo_normal_143.txt (open/close)
#        ./labels_fullempty\photo_normal_143.txt (full/empty)
# [INFO] label\photo_normal_144.xml ->
#        ./labels_openclose\photo_normal_144.txt (open/close)
#        ./labels_fullempty\photo_normal_144.txt (full/empty)
# [INFO] label\photo_normal_145.xml ->
#        ./labels_openclose\photo_normal_145.txt (open/close)
#        ./labels_fullempty\photo_normal_145.txt (full/empty)
# [INFO] label\photo_normal_146.xml ->
#        ./labels_openclose\photo_normal_146.txt (open/close)
#        ./labels_fullempty\photo_normal_146.txt (full/empty)
# [INFO] label\photo_normal_147.xml ->
#        ./labels_openclose\photo_normal_147.txt (open/close)
#        ./labels_fullempty\photo_normal_147.txt (full/empty)
# [INFO] label\photo_normal_148.xml ->
#        ./labels_openclose\photo_normal_148.txt (open/close)
#        ./labels_fullempty\photo_normal_148.txt (full/empty)
# [INFO] label\photo_normal_149.xml ->
#        ./labels_openclose\photo_normal_149.txt (open/close)
#        ./labels_fullempty\photo_normal_149.txt (full/empty)
# [INFO] label\photo_normal_150.xml ->
#        ./labels_openclose\photo_normal_150.txt (open/close)
#        ./labels_fullempty\photo_normal_150.txt (full/empty)
# [INFO] label\photo_normal_151.xml ->
#        ./labels_openclose\photo_normal_151.txt (open/close)
#        ./labels_fullempty\photo_normal_151.txt (full/empty)
# [INFO] label\photo_normal_152.xml ->
#        ./labels_openclose\photo_normal_152.txt (open/close)
#        ./labels_fullempty\photo_normal_152.txt (full/empty)
# [INFO] label\photo_normal_153.xml ->
#        ./labels_openclose\photo_normal_153.txt (open/close)
#        ./labels_fullempty\photo_normal_153.txt (full/empty)
# [INFO] label\photo_normal_154.xml ->
#        ./labels_openclose\photo_normal_154.txt (open/close)
#        ./labels_fullempty\photo_normal_154.txt (full/empty)
# [INFO] label\photo_normal_155.xml ->
#        ./labels_openclose\photo_normal_155.txt (open/close)
#        ./labels_fullempty\photo_normal_155.txt (full/empty)
# [INFO] label\photo_normal_156.xml ->
#        ./labels_openclose\photo_normal_156.txt (open/close)
#        ./labels_fullempty\photo_normal_156.txt (full/empty)
# [INFO] label\photo_normal_157.xml ->
#        ./labels_openclose\photo_normal_157.txt (open/close)
#        ./labels_fullempty\photo_normal_157.txt (full/empty)
# [INFO] label\photo_normal_158.xml ->
#        ./labels_openclose\photo_normal_158.txt (open/close)
#        ./labels_fullempty\photo_normal_158.txt (full/empty)
# [INFO] label\photo_normal_159.xml ->
#        ./labels_openclose\photo_normal_159.txt (open/close)
#        ./labels_fullempty\photo_normal_159.txt (full/empty)
# [INFO] label\photo_normal_160.xml ->
#        ./labels_openclose\photo_normal_160.txt (open/close)
#        ./labels_fullempty\photo_normal_160.txt (full/empty)
# [INFO] label\photo_normal_161.xml ->
#        ./labels_openclose\photo_normal_161.txt (open/close)
#        ./labels_fullempty\photo_normal_161.txt (full/empty)
# [INFO] label\photo_normal_162.xml ->
#        ./labels_openclose\photo_normal_162.txt (open/close)
#        ./labels_fullempty\photo_normal_162.txt (full/empty)
# [INFO] label\photo_normal_163.xml ->
#        ./labels_openclose\photo_normal_163.txt (open/close)
#        ./labels_fullempty\photo_normal_163.txt (full/empty)
# [INFO] label\photo_normal_164.xml ->
#        ./labels_openclose\photo_normal_164.txt (open/close)
#        ./labels_fullempty\photo_normal_164.txt (full/empty)
# [INFO] label\photo_normal_165.xml ->
#        ./labels_openclose\photo_normal_165.txt (open/close)
#        ./labels_fullempty\photo_normal_165.txt (full/empty)
# [INFO] label\photo_normal_166.xml ->
#        ./labels_openclose\photo_normal_166.txt (open/close)
#        ./labels_fullempty\photo_normal_166.txt (full/empty)
# [INFO] label\photo_normal_167.xml ->
#        ./labels_openclose\photo_normal_167.txt (open/close)
#        ./labels_fullempty\photo_normal_167.txt (full/empty)
# [INFO] label\photo_normal_168.xml ->
#        ./labels_openclose\photo_normal_168.txt (open/close)
#        ./labels_fullempty\photo_normal_168.txt (full/empty)
# [INFO] label\photo_normal_169.xml ->
#        ./labels_openclose\photo_normal_169.txt (open/close)
#        ./labels_fullempty\photo_normal_169.txt (full/empty)
# [INFO] label\photo_normal_170.xml ->
#        ./labels_openclose\photo_normal_170.txt (open/close)
#        ./labels_fullempty\photo_normal_170.txt (full/empty)
# [INFO] label\photo_normal_171.xml ->
#        ./labels_openclose\photo_normal_171.txt (open/close)
#        ./labels_fullempty\photo_normal_171.txt (full/empty)
# [INFO] label\photo_normal_172.xml ->
#        ./labels_openclose\photo_normal_172.txt (open/close)
#        ./labels_fullempty\photo_normal_172.txt (full/empty)
# [INFO] label\photo_normal_173.xml ->
#        ./labels_openclose\photo_normal_173.txt (open/close)
#        ./labels_fullempty\photo_normal_173.txt (full/empty)
# [INFO] label\photo_normal_174.xml ->
#        ./labels_openclose\photo_normal_174.txt (open/close)
#        ./labels_fullempty\photo_normal_174.txt (full/empty)
# [INFO] label\photo_normal_175.xml ->
#        ./labels_openclose\photo_normal_175.txt (open/close)
#        ./labels_fullempty\photo_normal_175.txt (full/empty)
# [INFO] label\photo_normal_176.xml ->
#        ./labels_openclose\photo_normal_176.txt (open/close)
#        ./labels_fullempty\photo_normal_176.txt (full/empty)
# [INFO] label\photo_normal_177.xml ->
#        ./labels_openclose\photo_normal_177.txt (open/close)
#        ./labels_fullempty\photo_normal_177.txt (full/empty)
# [INFO] label\photo_normal_178.xml ->
#        ./labels_openclose\photo_normal_178.txt (open/close)
#        ./labels_fullempty\photo_normal_178.txt (full/empty)
# [INFO] label\photo_normal_179.xml ->
#        ./labels_openclose\photo_normal_179.txt (open/close)
#        ./labels_fullempty\photo_normal_179.txt (full/empty)
# [INFO] label\photo_normal_180.xml ->
#        ./labels_openclose\photo_normal_180.txt (open/close)
#        ./labels_fullempty\photo_normal_180.txt (full/empty)
# [INFO] label\photo_normal_181.xml ->
#        ./labels_openclose\photo_normal_181.txt (open/close)
#        ./labels_fullempty\photo_normal_181.txt (full/empty)
# [INFO] label\photo_normal_182.xml ->
#        ./labels_openclose\photo_normal_182.txt (open/close)
#        ./labels_fullempty\photo_normal_182.txt (full/empty)
# [INFO] label\photo_normal_183.xml ->
#        ./labels_openclose\photo_normal_183.txt (open/close)
#        ./labels_fullempty\photo_normal_183.txt (full/empty)
# [INFO] label\photo_normal_184.xml ->
#        ./labels_openclose\photo_normal_184.txt (open/close)
#        ./labels_fullempty\photo_normal_184.txt (full/empty)
# [INFO] label\photo_normal_185.xml ->
#        ./labels_openclose\photo_normal_185.txt (open/close)
#        ./labels_fullempty\photo_normal_185.txt (full/empty)
# [INFO] label\photo_normal_186.xml ->
#        ./labels_openclose\photo_normal_186.txt (open/close)
#        ./labels_fullempty\photo_normal_186.txt (full/empty)
# [INFO] label\photo_normal_187.xml ->
#        ./labels_openclose\photo_normal_187.txt (open/close)
#        ./labels_fullempty\photo_normal_187.txt (full/empty)
# [INFO] label\photo_normal_188.xml ->
#        ./labels_openclose\photo_normal_188.txt (open/close)
#        ./labels_fullempty\photo_normal_188.txt (full/empty)
# [INFO] label\photo_normal_189.xml ->
#        ./labels_openclose\photo_normal_189.txt (open/close)
#        ./labels_fullempty\photo_normal_189.txt (full/empty)
# [INFO] label\photo_normal_190.xml ->
#        ./labels_openclose\photo_normal_190.txt (open/close)
#        ./labels_fullempty\photo_normal_190.txt (full/empty)
# [INFO] label\photo_normal_191.xml ->
#        ./labels_openclose\photo_normal_191.txt (open/close)
#        ./labels_fullempty\photo_normal_191.txt (full/empty)
# [INFO] label\photo_normal_192.xml ->
#        ./labels_openclose\photo_normal_192.txt (open/close)
#        ./labels_fullempty\photo_normal_192.txt (full/empty)
# [INFO] label\photo_normal_193.xml ->
#        ./labels_openclose\photo_normal_193.txt (open/close)
#        ./labels_fullempty\photo_normal_193.txt (full/empty)
# [INFO] label\photo_normal_194.xml ->
#        ./labels_openclose\photo_normal_194.txt (open/close)
#        ./labels_fullempty\photo_normal_194.txt (full/empty)
# [INFO] label\photo_normal_195.xml ->
#        ./labels_openclose\photo_normal_195.txt (open/close)
#        ./labels_fullempty\photo_normal_195.txt (full/empty)
# [INFO] label\photo_normal_196.xml ->
#        ./labels_openclose\photo_normal_196.txt (open/close)
#        ./labels_fullempty\photo_normal_196.txt (full/empty)
# [INFO] label\photo_normal_197.xml ->
#        ./labels_openclose\photo_normal_197.txt (open/close)
#        ./labels_fullempty\photo_normal_197.txt (full/empty)
# [INFO] label\photo_normal_198.xml ->
#        ./labels_openclose\photo_normal_198.txt (open/close)
#        ./labels_fullempty\photo_normal_198.txt (full/empty)
# [INFO] label\photo_normal_199.xml ->
#        ./labels_openclose\photo_normal_199.txt (open/close)
#        ./labels_fullempty\photo_normal_199.txt (full/empty)
# [INFO] label\photo_normal_200.xml ->
#        ./labels_openclose\photo_normal_200.txt (open/close)
#        ./labels_fullempty\photo_normal_200.txt (full/empty)
# [INFO] label\photo_normal_201.xml ->
#        ./labels_openclose\photo_normal_201.txt (open/close)
#        ./labels_fullempty\photo_normal_201.txt (full/empty)
# [INFO] label\photo_normal_202.xml ->
#        ./labels_openclose\photo_normal_202.txt (open/close)
#        ./labels_fullempty\photo_normal_202.txt (full/empty)
# [INFO] label\photo_normal_203.xml ->
#        ./labels_openclose\photo_normal_203.txt (open/close)
#        ./labels_fullempty\photo_normal_203.txt (full/empty)
# [INFO] label\photo_normal_204.xml ->
#        ./labels_openclose\photo_normal_204.txt (open/close)
#        ./labels_fullempty\photo_normal_204.txt (full/empty)
# [INFO] label\photo_normal_205.xml ->
#        ./labels_openclose\photo_normal_205.txt (open/close)
#        ./labels_fullempty\photo_normal_205.txt (full/empty)
# [INFO] label\photo_normal_206.xml ->
#        ./labels_openclose\photo_normal_206.txt (open/close)
#        ./labels_fullempty\photo_normal_206.txt (full/empty)
# [INFO] label\photo_normal_309.xml ->
#        ./labels_openclose\photo_normal_309.txt (open/close)
#        ./labels_fullempty\photo_normal_309.txt (full/empty)
# [INFO] label\photo_normal_310.xml ->
#        ./labels_openclose\photo_normal_310.txt (open/close)
#        ./labels_fullempty\photo_normal_310.txt (full/empty)
# [INFO] label\photo_normal_311.xml ->
#        ./labels_openclose\photo_normal_311.txt (open/close)
#        ./labels_fullempty\photo_normal_311.txt (full/empty)
# [INFO] label\photo_normal_312.xml ->
#        ./labels_openclose\photo_normal_312.txt (open/close)
#        ./labels_fullempty\photo_normal_312.txt (full/empty)
# [INFO] label\photo_normal_313.xml ->
#        ./labels_openclose\photo_normal_313.txt (open/close)
#        ./labels_fullempty\photo_normal_313.txt (full/empty)
# [INFO] label\photo_normal_314.xml ->
#        ./labels_openclose\photo_normal_314.txt (open/close)
#        ./labels_fullempty\photo_normal_314.txt (full/empty)
# [INFO] label\photo_normal_315.xml ->
#        ./labels_openclose\photo_normal_315.txt (open/close)
#        ./labels_fullempty\photo_normal_315.txt (full/empty)
# [INFO] label\photo_normal_316.xml ->
#        ./labels_openclose\photo_normal_316.txt (open/close)
#        ./labels_fullempty\photo_normal_316.txt (full/empty)
# [INFO] label\photo_normal_317.xml ->
#        ./labels_openclose\photo_normal_317.txt (open/close)
#        ./labels_fullempty\photo_normal_317.txt (full/empty)
# [INFO] label\photo_normal_318.xml ->
#        ./labels_openclose\photo_normal_318.txt (open/close)
#        ./labels_fullempty\photo_normal_318.txt (full/empty)
# [INFO] label\photo_normal_319.xml ->
#        ./labels_openclose\photo_normal_319.txt (open/close)
#        ./labels_fullempty\photo_normal_319.txt (full/empty)
# [INFO] label\photo_normal_320.xml ->
#        ./labels_openclose\photo_normal_320.txt (open/close)
#        ./labels_fullempty\photo_normal_320.txt (full/empty)
# [INFO] label\photo_normal_321.xml ->
#        ./labels_openclose\photo_normal_321.txt (open/close)
#        ./labels_fullempty\photo_normal_321.txt (full/empty)
# [INFO] label\photo_normal_322.xml ->
#        ./labels_openclose\photo_normal_322.txt (open/close)
#        ./labels_fullempty\photo_normal_322.txt (full/empty)
# [INFO] label\photo_normal_323.xml ->
#        ./labels_openclose\photo_normal_323.txt (open/close)
#        ./labels_fullempty\photo_normal_323.txt (full/empty)
# [INFO] label\photo_normal_324.xml ->
#        ./labels_openclose\photo_normal_324.txt (open/close)
#        ./labels_fullempty\photo_normal_324.txt (full/empty)
# [INFO] label\photo_normal_325.xml ->
#        ./labels_openclose\photo_normal_325.txt (open/close)
#        ./labels_fullempty\photo_normal_325.txt (full/empty)
# [INFO] label\photo_normal_326.xml ->
#        ./labels_openclose\photo_normal_326.txt (open/close)
#        ./labels_fullempty\photo_normal_326.txt (full/empty)
# [INFO] label\photo_normal_327.xml ->
#        ./labels_openclose\photo_normal_327.txt (open/close)
#        ./labels_fullempty\photo_normal_327.txt (full/empty)
# [INFO] label\photo_normal_328.xml ->
#        ./labels_openclose\photo_normal_328.txt (open/close)
#        ./labels_fullempty\photo_normal_328.txt (full/empty)
# [INFO] label\photo_normal_329.xml ->
#        ./labels_openclose\photo_normal_329.txt (open/close)
#        ./labels_fullempty\photo_normal_329.txt (full/empty)
# [INFO] label\photo_normal_330.xml ->
#        ./labels_openclose\photo_normal_330.txt (open/close)
#        ./labels_fullempty\photo_normal_330.txt (full/empty)
# [INFO] label\photo_normal_331.xml ->
#        ./labels_openclose\photo_normal_331.txt (open/close)
#        ./labels_fullempty\photo_normal_331.txt (full/empty)
# [INFO] label\photo_normal_332.xml ->
#        ./labels_openclose\photo_normal_332.txt (open/close)
#        ./labels_fullempty\photo_normal_332.txt (full/empty)
# [INFO] label\photo_normal_333.xml ->
#        ./labels_openclose\photo_normal_333.txt (open/close)
#        ./labels_fullempty\photo_normal_333.txt (full/empty)
# [INFO] label\photo_normal_334.xml ->
#        ./labels_openclose\photo_normal_334.txt (open/close)
#        ./labels_fullempty\photo_normal_334.txt (full/empty)
# [INFO] label\photo_normal_335.xml ->
#        ./labels_openclose\photo_normal_335.txt (open/close)
#        ./labels_fullempty\photo_normal_335.txt (full/empty)
# [INFO] label\photo_normal_336.xml ->
#        ./labels_openclose\photo_normal_336.txt (open/close)
#        ./labels_fullempty\photo_normal_336.txt (full/empty)
# [INFO] label\photo_normal_337.xml ->
#        ./labels_openclose\photo_normal_337.txt (open/close)
#        ./labels_fullempty\photo_normal_337.txt (full/empty)
# [INFO] label\photo_normal_338.xml ->
#        ./labels_openclose\photo_normal_338.txt (open/close)
#        ./labels_fullempty\photo_normal_338.txt (full/empty)
# [INFO] label\photo_normal_339.xml ->
#        ./labels_openclose\photo_normal_339.txt (open/close)
#        ./labels_fullempty\photo_normal_339.txt (full/empty)
# [INFO] label\photo_normal_340.xml ->
#        ./labels_openclose\photo_normal_340.txt (open/close)
#        ./labels_fullempty\photo_normal_340.txt (full/empty)
# [INFO] label\photo_normal_341.xml ->
#        ./labels_openclose\photo_normal_341.txt (open/close)
#        ./labels_fullempty\photo_normal_341.txt (full/empty)
# [INFO] label\photo_normal_342.xml ->
#        ./labels_openclose\photo_normal_342.txt (open/close)
#        ./labels_fullempty\photo_normal_342.txt (full/empty)
# [INFO] label\photo_normal_343.xml ->
#        ./labels_openclose\photo_normal_343.txt (open/close)
#        ./labels_fullempty\photo_normal_343.txt (full/empty)
# [INFO] label\photo_normal_344.xml ->
#        ./labels_openclose\photo_normal_344.txt (open/close)
#        ./labels_fullempty\photo_normal_344.txt (full/empty)
# [INFO] label\photo_normal_345.xml ->
#        ./labels_openclose\photo_normal_345.txt (open/close)
#        ./labels_fullempty\photo_normal_345.txt (full/empty)
# [INFO] label\photo_normal_346.xml ->
#        ./labels_openclose\photo_normal_346.txt (open/close)
#        ./labels_fullempty\photo_normal_346.txt (full/empty)
# [INFO] label\photo_normal_347.xml ->
#        ./labels_openclose\photo_normal_347.txt (open/close)
#        ./labels_fullempty\photo_normal_347.txt (full/empty)
# [INFO] label\photo_normal_348.xml ->
#        ./labels_openclose\photo_normal_348.txt (open/close)
#        ./labels_fullempty\photo_normal_348.txt (full/empty)
# [INFO] label\photo_normal_349.xml ->
#        ./labels_openclose\photo_normal_349.txt (open/close)
#        ./labels_fullempty\photo_normal_349.txt (full/empty)
# [INFO] label\photo_normal_350.xml ->
#        ./labels_openclose\photo_normal_350.txt (open/close)
#        ./labels_fullempty\photo_normal_350.txt (full/empty)
# [INFO] label\photo_normal_351.xml ->
#        ./labels_openclose\photo_normal_351.txt (open/close)
#        ./labels_fullempty\photo_normal_351.txt (full/empty)
# [INFO] label\photo_normal_352.xml ->
#        ./labels_openclose\photo_normal_352.txt (open/close)
#        ./labels_fullempty\photo_normal_352.txt (full/empty)
# [INFO] label\photo_normal_353.xml ->
#        ./labels_openclose\photo_normal_353.txt (open/close)
#        ./labels_fullempty\photo_normal_353.txt (full/empty)
# [INFO] label\photo_normal_354.xml ->
#        ./labels_openclose\photo_normal_354.txt (open/close)
#        ./labels_fullempty\photo_normal_354.txt (full/empty)
# [INFO] label\photo_normal_355.xml ->
#        ./labels_openclose\photo_normal_355.txt (open/close)
#        ./labels_fullempty\photo_normal_355.txt (full/empty)
# [INFO] label\photo_normal_356.xml ->
#        ./labels_openclose\photo_normal_356.txt (open/close)
#        ./labels_fullempty\photo_normal_356.txt (full/empty)
# [INFO] label\photo_normal_357.xml ->
#        ./labels_openclose\photo_normal_357.txt (open/close)
#        ./labels_fullempty\photo_normal_357.txt (full/empty)
# [INFO] label\photo_normal_358.xml ->
#        ./labels_openclose\photo_normal_358.txt (open/close)
#        ./labels_fullempty\photo_normal_358.txt (full/empty)
# [INFO] label\photo_normal_359.xml ->
#        ./labels_openclose\photo_normal_359.txt (open/close)
#        ./labels_fullempty\photo_normal_359.txt (full/empty)
# [INFO] label\photo_normal_360.xml ->
#        ./labels_openclose\photo_normal_360.txt (open/close)
#        ./labels_fullempty\photo_normal_360.txt (full/empty)
# [INFO] label\photo_normal_361.xml ->
#        ./labels_openclose\photo_normal_361.txt (open/close)
#        ./labels_fullempty\photo_normal_361.txt (full/empty)
# [INFO] label\photo_normal_362.xml ->
#        ./labels_openclose\photo_normal_362.txt (open/close)
#        ./labels_fullempty\photo_normal_362.txt (full/empty)
# [INFO] label\photo_normal_363.xml ->
#        ./labels_openclose\photo_normal_363.txt (open/close)
#        ./labels_fullempty\photo_normal_363.txt (full/empty)
# [INFO] label\photo_normal_364.xml ->
#        ./labels_openclose\photo_normal_364.txt (open/close)
#        ./labels_fullempty\photo_normal_364.txt (full/empty)
# [INFO] label\photo_normal_365.xml ->
#        ./labels_openclose\photo_normal_365.txt (open/close)
#        ./labels_fullempty\photo_normal_365.txt (full/empty)
# [INFO] label\photo_normal_366.xml ->
#        ./labels_openclose\photo_normal_366.txt (open/close)
#        ./labels_fullempty\photo_normal_366.txt (full/empty)
# [INFO] label\photo_normal_367.xml ->
#        ./labels_openclose\photo_normal_367.txt (open/close)
#        ./labels_fullempty\photo_normal_367.txt (full/empty)
# [INFO] label\photo_normal_368.xml ->
#        ./labels_openclose\photo_normal_368.txt (open/close)
#        ./labels_fullempty\photo_normal_368.txt (full/empty)
# [INFO] label\photo_normal_369.xml ->
#        ./labels_openclose\photo_normal_369.txt (open/close)
#        ./labels_fullempty\photo_normal_369.txt (full/empty)
# [INFO] label\photo_normal_370.xml ->
#        ./labels_openclose\photo_normal_370.txt (open/close)
#        ./labels_fullempty\photo_normal_370.txt (full/empty)
# [INFO] label\photo_normal_371.xml ->
#        ./labels_openclose\photo_normal_371.txt (open/close)
#        ./labels_fullempty\photo_normal_371.txt (full/empty)
# [INFO] label\photo_normal_372.xml ->
#        ./labels_openclose\photo_normal_372.txt (open/close)
#        ./labels_fullempty\photo_normal_372.txt (full/empty)
# [INFO] label\photo_normal_373.xml ->
#        ./labels_openclose\photo_normal_373.txt (open/close)
#        ./labels_fullempty\photo_normal_373.txt (full/empty)
# [INFO] label\photo_normal_374.xml ->
#        ./labels_openclose\photo_normal_374.txt (open/close)
#        ./labels_fullempty\photo_normal_374.txt (full/empty)
# [INFO] label\photo_normal_375.xml ->
#        ./labels_openclose\photo_normal_375.txt (open/close)
#        ./labels_fullempty\photo_normal_375.txt (full/empty)
# [INFO] label\photo_normal_376.xml ->
#        ./labels_openclose\photo_normal_376.txt (open/close)
#        ./labels_fullempty\photo_normal_376.txt (full/empty)
# [INFO] label\photo_normal_377.xml ->
#        ./labels_openclose\photo_normal_377.txt (open/close)
#        ./labels_fullempty\photo_normal_377.txt (full/empty)
# [INFO] label\photo_normal_378.xml ->
#        ./labels_openclose\photo_normal_378.txt (open/close)
#        ./labels_fullempty\photo_normal_378.txt (full/empty)
# [INFO] label\photo_normal_379.xml ->
#        ./labels_openclose\photo_normal_379.txt (open/close)
#        ./labels_fullempty\photo_normal_379.txt (full/empty)
# [INFO] label\photo_normal_380.xml ->
#        ./labels_openclose\photo_normal_380.txt (open/close)
#        ./labels_fullempty\photo_normal_380.txt (full/empty)
# [INFO] label\photo_normal_381.xml ->
#        ./labels_openclose\photo_normal_381.txt (open/close)
#        ./labels_fullempty\photo_normal_381.txt (full/empty)
# [INFO] label\photo_normal_382.xml ->
#        ./labels_openclose\photo_normal_382.txt (open/close)
#        ./labels_fullempty\photo_normal_382.txt (full/empty)
# [INFO] label\photo_normal_383.xml ->
#        ./labels_openclose\photo_normal_383.txt (open/close)
#        ./labels_fullempty\photo_normal_383.txt (full/empty)
# [INFO] label\photo_normal_384.xml ->
#        ./labels_openclose\photo_normal_384.txt (open/close)
#        ./labels_fullempty\photo_normal_384.txt (full/empty)
# [INFO] label\photo_normal_385.xml ->
#        ./labels_openclose\photo_normal_385.txt (open/close)
#        ./labels_fullempty\photo_normal_385.txt (full/empty)
# [INFO] label\photo_normal_386.xml ->
#        ./labels_openclose\photo_normal_386.txt (open/close)
#        ./labels_fullempty\photo_normal_386.txt (full/empty)
# [INFO] label\photo_normal_387.xml ->
#        ./labels_openclose\photo_normal_387.txt (open/close)
#        ./labels_fullempty\photo_normal_387.txt (full/empty)
# [INFO] label\photo_normal_388.xml ->
#        ./labels_openclose\photo_normal_388.txt (open/close)
#        ./labels_fullempty\photo_normal_388.txt (full/empty)
# [INFO] label\photo_normal_389.xml ->
#        ./labels_openclose\photo_normal_389.txt (open/close)
#        ./labels_fullempty\photo_normal_389.txt (full/empty)
# [INFO] label\photo_normal_390.xml ->
#        ./labels_openclose\photo_normal_390.txt (open/close)
#        ./labels_fullempty\photo_normal_390.txt (full/empty)
# [INFO] label\photo_normal_391.xml ->
#        ./labels_openclose\photo_normal_391.txt (open/close)
#        ./labels_fullempty\photo_normal_391.txt (full/empty)
# [INFO] label\photo_normal_392.xml ->
#        ./labels_openclose\photo_normal_392.txt (open/close)
#        ./labels_fullempty\photo_normal_392.txt (full/empty)
# [INFO] label\photo_normal_393.xml ->
#        ./labels_openclose\photo_normal_393.txt (open/close)
#        ./labels_fullempty\photo_normal_393.txt (full/empty)
# [INFO] label\photo_normal_394.xml ->
#        ./labels_openclose\photo_normal_394.txt (open/close)
#        ./labels_fullempty\photo_normal_394.txt (full/empty)
# [INFO] label\photo_normal_395.xml ->
#        ./labels_openclose\photo_normal_395.txt (open/close)
#        ./labels_fullempty\photo_normal_395.txt (full/empty)
# [INFO] label\photo_normal_396.xml ->
#        ./labels_openclose\photo_normal_396.txt (open/close)
#        ./labels_fullempty\photo_normal_396.txt (full/empty)
# [INFO] label\photo_normal_397.xml ->
#        ./labels_openclose\photo_normal_397.txt (open/close)
#        ./labels_fullempty\photo_normal_397.txt (full/empty)
# [INFO] label\photo_normal_398.xml ->
#        ./labels_openclose\photo_normal_398.txt (open/close)
#        ./labels_fullempty\photo_normal_398.txt (full/empty)
# [INFO] label\photo_normal_399.xml ->
#        ./labels_openclose\photo_normal_399.txt (open/close)
#        ./labels_fullempty\photo_normal_399.txt (full/empty)
# [INFO] label\photo_normal_400.xml ->
#        ./labels_openclose\photo_normal_400.txt (open/close)
#        ./labels_fullempty\photo_normal_400.txt (full/empty)
# [INFO] label\photo_normal_401.xml ->
#        ./labels_openclose\photo_normal_401.txt (open/close)
#        ./labels_fullempty\photo_normal_401.txt (full/empty)
# [INFO] label\photo_normal_402.xml ->
#        ./labels_openclose\photo_normal_402.txt (open/close)
#        ./labels_fullempty\photo_normal_402.txt (full/empty)
# [INFO] label\photo_normal_403.xml ->
#        ./labels_openclose\photo_normal_403.txt (open/close)
#        ./labels_fullempty\photo_normal_403.txt (full/empty)
# [INFO] label\photo_normal_404.xml ->
#        ./labels_openclose\photo_normal_404.txt (open/close)
#        ./labels_fullempty\photo_normal_404.txt (full/empty)
# [INFO] label\photo_normal_405.xml ->
#        ./labels_openclose\photo_normal_405.txt (open/close)
#        ./labels_fullempty\photo_normal_405.txt (full/empty)
# [INFO] label\photo_normal_406.xml ->
#        ./labels_openclose\photo_normal_406.txt (open/close)
#        ./labels_fullempty\photo_normal_406.txt (full/empty)
# [INFO] label\photo_normal_407.xml ->
#        ./labels_openclose\photo_normal_407.txt (open/close)
#        ./labels_fullempty\photo_normal_407.txt (full/empty)
# [INFO] label\photo_normal_408.xml ->
#        ./labels_openclose\photo_normal_408.txt (open/close)
#        ./labels_fullempty\photo_normal_408.txt (full/empty)
# [INFO] label\photo_normal_414.xml ->
#        ./labels_openclose\photo_normal_414.txt (open/close)
#        ./labels_fullempty\photo_normal_414.txt (full/empty)
# [INFO] label\photo_normal_415.xml ->
#        ./labels_openclose\photo_normal_415.txt (open/close)
#        ./labels_fullempty\photo_normal_415.txt (full/empty)
# [INFO] label\photo_normal_416.xml ->
#        ./labels_openclose\photo_normal_416.txt (open/close)
#        ./labels_fullempty\photo_normal_416.txt (full/empty)
# [INFO] label\photo_normal_417.xml ->
# ...
#        ./labels_openclose\photo_normal_306.txt (open/close)
#        ./labels_fullempty\photo_normal_306.txt (full/empty)
# [INFO] label\photo_normal_305.xml ->
#        ./labels_openclose\photo_normal_305.txt (open/close)
#        ./labels_fullempty\photo_normal_305.txt (full/empty)
# [INFO] label\photo_normal_304.xml ->
#        ./labels_openclose\photo_normal_304.txt (open/close)
#        ./labels_fullempty\photo_normal_304.txt (full/empty)
# [INFO] label\photo_normal_303.xml ->
#        ./labels_openclose\photo_normal_303.txt (open/close)
#        ./labels_fullempty\photo_normal_303.txt (full/empty)
# [INFO] label\photo_normal_302.xml ->
#        ./labels_openclose\photo_normal_302.txt (open/close)
#        ./labels_fullempty\photo_normal_302.txt (full/empty)
# [INFO] label\photo_normal_308.xml ->
#        ./labels_openclose\photo_normal_308.txt (open/close)
#        ./labels_fullempty\photo_normal_308.txt (full/empty)
# [INFO] label\photo_normal_301.xml ->
#        ./labels_openclose\photo_normal_301.txt (open/close)
#        ./labels_fullempty\photo_normal_301.txt (full/empty)
# [INFO] label\photo_normal_300.xml ->
#        ./labels_openclose\photo_normal_300.txt (open/close)
#        ./labels_fullempty\photo_normal_300.txt (full/empty)
# [INFO] label\photo_normal_299.xml ->
#        ./labels_openclose\photo_normal_299.txt (open/close)
#        ./labels_fullempty\photo_normal_299.txt (full/empty)
# [INFO] label\photo_normal_298.xml ->
#        ./labels_openclose\photo_normal_298.txt (open/close)
#        ./labels_fullempty\photo_normal_298.txt (full/empty)
# [INFO] label\photo_normal_297.xml ->
#        ./labels_openclose\photo_normal_297.txt (open/close)
#        ./labels_fullempty\photo_normal_297.txt (full/empty)
# [INFO] label\photo_normal_296.xml ->
#        ./labels_openclose\photo_normal_296.txt (open/close)
#        ./labels_fullempty\photo_normal_296.txt (full/empty)
# [INFO] label\photo_normal_295.xml ->
#        ./labels_openclose\photo_normal_295.txt (open/close)
#        ./labels_fullempty\photo_normal_295.txt (full/empty)
# [INFO] label\photo_normal_294.xml ->
#        ./labels_openclose\photo_normal_294.txt (open/close)
#        ./labels_fullempty\photo_normal_294.txt (full/empty)
# [INFO] label\photo_normal_293.xml ->
#        ./labels_openclose\photo_normal_293.txt (open/close)
#        ./labels_fullempty\photo_normal_293.txt (full/empty)
# [INFO] label\photo_normal_292.xml ->
#        ./labels_openclose\photo_normal_292.txt (open/close)
#        ./labels_fullempty\photo_normal_292.txt (full/empty)
# [INFO] label\photo_normal_291.xml ->
#        ./labels_openclose\photo_normal_291.txt (open/close)
#        ./labels_fullempty\photo_normal_291.txt (full/empty)
# [INFO] label\photo_normal_290.xml ->
#        ./labels_openclose\photo_normal_290.txt (open/close)
#        ./labels_fullempty\photo_normal_290.txt (full/empty)
# [INFO] label\photo_normal_289.xml ->
#        ./labels_openclose\photo_normal_289.txt (open/close)
#        ./labels_fullempty\photo_normal_289.txt (full/empty)
# [INFO] label\photo_normal_288.xml ->
#        ./labels_openclose\photo_normal_288.txt (open/close)
#        ./labels_fullempty\photo_normal_288.txt (full/empty)
# [INFO] label\photo_normal_287.xml ->
#        ./labels_openclose\photo_normal_287.txt (open/close)
#        ./labels_fullempty\photo_normal_287.txt (full/empty)
# [INFO] label\photo_normal_286.xml ->
#        ./labels_openclose\photo_normal_286.txt (open/close)
#        ./labels_fullempty\photo_normal_286.txt (full/empty)
# [INFO] label\photo_normal_285.xml ->
#        ./labels_openclose\photo_normal_285.txt (open/close)
#        ./labels_fullempty\photo_normal_285.txt (full/empty)
# [INFO] label\photo_normal_284.xml ->
#        ./labels_openclose\photo_normal_284.txt (open/close)
#        ./labels_fullempty\photo_normal_284.txt (full/empty)
# [INFO] label\photo_normal_283.xml ->
#        ./labels_openclose\photo_normal_283.txt (open/close)
#        ./labels_fullempty\photo_normal_283.txt (full/empty)
# [INFO] label\photo_normal_282.xml ->
#        ./labels_openclose\photo_normal_282.txt (open/close)
#        ./labels_fullempty\photo_normal_282.txt (full/empty)
# [INFO] label\photo_normal_281.xml ->
#        ./labels_openclose\photo_normal_281.txt (open/close)
#        ./labels_fullempty\photo_normal_281.txt (full/empty)
# [INFO] label\photo_normal_280.xml ->
#        ./labels_openclose\photo_normal_280.txt (open/close)
#        ./labels_fullempty\photo_normal_280.txt (full/empty)
# [INFO] label\photo_normal_279.xml ->
#        ./labels_openclose\photo_normal_279.txt (open/close)
#        ./labels_fullempty\photo_normal_279.txt (full/empty)
# [INFO] label\photo_normal_278.xml ->
#        ./labels_openclose\photo_normal_278.txt (open/close)
#        ./labels_fullempty\photo_normal_278.txt (full/empty)
# [INFO] label\photo_normal_277.xml ->
#        ./labels_openclose\photo_normal_277.txt (open/close)
#        ./labels_fullempty\photo_normal_277.txt (full/empty)
# [INFO] label\photo_normal_276.xml ->
#        ./labels_openclose\photo_normal_276.txt (open/close)
#        ./labels_fullempty\photo_normal_276.txt (full/empty)
# [INFO] label\photo_normal_275.xml ->
#        ./labels_openclose\photo_normal_275.txt (open/close)
#        ./labels_fullempty\photo_normal_275.txt (full/empty)
# [INFO] label\photo_normal_274.xml ->
#        ./labels_openclose\photo_normal_274.txt (open/close)
#        ./labels_fullempty\photo_normal_274.txt (full/empty)
# [INFO] label\photo_normal_273.xml ->
#        ./labels_openclose\photo_normal_273.txt (open/close)
#        ./labels_fullempty\photo_normal_273.txt (full/empty)
# [INFO] label\photo_normal_272.xml ->
#        ./labels_openclose\photo_normal_272.txt (open/close)
#        ./labels_fullempty\photo_normal_272.txt (full/empty)
# [INFO] label\photo_normal_271.xml ->
#        ./labels_openclose\photo_normal_271.txt (open/close)
#        ./labels_fullempty\photo_normal_271.txt (full/empty)
# [INFO] label\photo_normal_270.xml ->
#        ./labels_openclose\photo_normal_270.txt (open/close)
#        ./labels_fullempty\photo_normal_270.txt (full/empty)
# [INFO] label\photo_normal_269.xml ->
#        ./labels_openclose\photo_normal_269.txt (open/close)
#        ./labels_fullempty\photo_normal_269.txt (full/empty)
# [INFO] label\photo_normal_268.xml ->
#        ./labels_openclose\photo_normal_268.txt (open/close)
#        ./labels_fullempty\photo_normal_268.txt (full/empty)
# [INFO] label\photo_normal_266.xml ->
#        ./labels_openclose\photo_normal_266.txt (open/close)
#        ./labels_fullempty\photo_normal_266.txt (full/empty)
# [INFO] label\photo_normal_267.xml ->
#        ./labels_openclose\photo_normal_267.txt (open/close)
#        ./labels_fullempty\photo_normal_267.txt (full/empty)
# [INFO] label\photo_normal_265.xml ->
#        ./labels_openclose\photo_normal_265.txt (open/close)
#        ./labels_fullempty\photo_normal_265.txt (full/empty)
# [INFO] label\photo_normal_264.xml ->
#        ./labels_openclose\photo_normal_264.txt (open/close)
#        ./labels_fullempty\photo_normal_264.txt (full/empty)
# [INFO] label\photo_normal_263.xml ->
#        ./labels_openclose\photo_normal_263.txt (open/close)
#        ./labels_fullempty\photo_normal_263.txt (full/empty)
# [INFO] label\photo_normal_262.xml ->
#        ./labels_openclose\photo_normal_262.txt (open/close)
#        ./labels_fullempty\photo_normal_262.txt (full/empty)
# [INFO] label\photo_normal_261.xml ->
#        ./labels_openclose\photo_normal_261.txt (open/close)
#        ./labels_fullempty\photo_normal_261.txt (full/empty)
# [INFO] label\photo_normal_260.xml ->
#        ./labels_openclose\photo_normal_260.txt (open/close)
#        ./labels_fullempty\photo_normal_260.txt (full/empty)
# [INFO] label\photo_normal_259.xml ->
#        ./labels_openclose\photo_normal_259.txt (open/close)
#        ./labels_fullempty\photo_normal_259.txt (full/empty)
# [INFO] label\photo_normal_258.xml ->
#        ./labels_openclose\photo_normal_258.txt (open/close)
#        ./labels_fullempty\photo_normal_258.txt (full/empty)
# [INFO] label\photo_normal_257.xml ->
#        ./labels_openclose\photo_normal_257.txt (open/close)
#        ./labels_fullempty\photo_normal_257.txt (full/empty)
# [INFO] label\photo_normal_256.xml ->
#        ./labels_openclose\photo_normal_256.txt (open/close)
#        ./labels_fullempty\photo_normal_256.txt (full/empty)
# [INFO] label\photo_normal_255.xml ->
#        ./labels_openclose\photo_normal_255.txt (open/close)
#        ./labels_fullempty\photo_normal_255.txt (full/empty)
# [INFO] label\photo_normal_254.xml ->
#        ./labels_openclose\photo_normal_254.txt (open/close)
#        ./labels_fullempty\photo_normal_254.txt (full/empty)
# [INFO] label\photo_normal_253.xml ->
#        ./labels_openclose\photo_normal_253.txt (open/close)
#        ./labels_fullempty\photo_normal_253.txt (full/empty)
# [INFO] label\photo_normal_252.xml ->
#        ./labels_openclose\photo_normal_252.txt (open/close)
#        ./labels_fullempty\photo_normal_252.txt (full/empty)
# [INFO] label\photo_normal_251.xml ->
#        ./labels_openclose\photo_normal_251.txt (open/close)
#        ./labels_fullempty\photo_normal_251.txt (full/empty)
# [INFO] label\photo_normal_250.xml ->
#        ./labels_openclose\photo_normal_250.txt (open/close)
#        ./labels_fullempty\photo_normal_250.txt (full/empty)
# [INFO] label\photo_normal_249.xml ->
#        ./labels_openclose\photo_normal_249.txt (open/close)
#        ./labels_fullempty\photo_normal_249.txt (full/empty)
# [INFO] label\photo_normal_248.xml ->
#        ./labels_openclose\photo_normal_248.txt (open/close)
#        ./labels_fullempty\photo_normal_248.txt (full/empty)
# [INFO] label\photo_normal_247.xml ->
#        ./labels_openclose\photo_normal_247.txt (open/close)
#        ./labels_fullempty\photo_normal_247.txt (full/empty)
# [INFO] label\photo_normal_246.xml ->
#        ./labels_openclose\photo_normal_246.txt (open/close)
#        ./labels_fullempty\photo_normal_246.txt (full/empty)
# [INFO] label\photo_normal_245.xml ->
#        ./labels_openclose\photo_normal_245.txt (open/close)
#        ./labels_fullempty\photo_normal_245.txt (full/empty)
# [INFO] label\photo_normal_244.xml ->
#        ./labels_openclose\photo_normal_244.txt (open/close)
#        ./labels_fullempty\photo_normal_244.txt (full/empty)
# [INFO] label\photo_normal_243.xml ->
#        ./labels_openclose\photo_normal_243.txt (open/close)
#        ./labels_fullempty\photo_normal_243.txt (full/empty)
# [INFO] label\photo_normal_242.xml ->
#        ./labels_openclose\photo_normal_242.txt (open/close)
#        ./labels_fullempty\photo_normal_242.txt (full/empty)
# [INFO] label\photo_normal_241.xml ->
#        ./labels_openclose\photo_normal_241.txt (open/close)
#        ./labels_fullempty\photo_normal_241.txt (full/empty)
# [INFO] label\photo_normal_240.xml ->
#        ./labels_openclose\photo_normal_240.txt (open/close)
#        ./labels_fullempty\photo_normal_240.txt (full/empty)
# [INFO] label\photo_normal_239.xml ->
#        ./labels_openclose\photo_normal_239.txt (open/close)
#        ./labels_fullempty\photo_normal_239.txt (full/empty)
# [INFO] label\photo_normal_238.xml ->
#        ./labels_openclose\photo_normal_238.txt (open/close)
#        ./labels_fullempty\photo_normal_238.txt (full/empty)
# [INFO] label\photo_normal_237.xml ->
#        ./labels_openclose\photo_normal_237.txt (open/close)
#        ./labels_fullempty\photo_normal_237.txt (full/empty)
# [INFO] label\photo_normal_236.xml ->
#        ./labels_openclose\photo_normal_236.txt (open/close)
#        ./labels_fullempty\photo_normal_236.txt (full/empty)
# [INFO] label\photo_normal_235.xml ->
#        ./labels_openclose\photo_normal_235.txt (open/close)
#        ./labels_fullempty\photo_normal_235.txt (full/empty)
# [INFO] label\photo_normal_234.xml ->
#        ./labels_openclose\photo_normal_234.txt (open/close)
#        ./labels_fullempty\photo_normal_234.txt (full/empty)
# [INFO] label\photo_normal_233.xml ->
#        ./labels_openclose\photo_normal_233.txt (open/close)
#        ./labels_fullempty\photo_normal_233.txt (full/empty)
# [INFO] label\photo_normal_232.xml ->
#        ./labels_openclose\photo_normal_232.txt (open/close)
#        ./labels_fullempty\photo_normal_232.txt (full/empty)
# [INFO] label\photo_normal_231.xml ->
#        ./labels_openclose\photo_normal_231.txt (open/close)
#        ./labels_fullempty\photo_normal_231.txt (full/empty)
# [INFO] label\photo_normal_230.xml ->
#        ./labels_openclose\photo_normal_230.txt (open/close)
#        ./labels_fullempty\photo_normal_230.txt (full/empty)
# [INFO] label\photo_normal_229.xml ->
#        ./labels_openclose\photo_normal_229.txt (open/close)
#        ./labels_fullempty\photo_normal_229.txt (full/empty)
# [INFO] label\photo_normal_228.xml ->
#        ./labels_openclose\photo_normal_228.txt (open/close)
#        ./labels_fullempty\photo_normal_228.txt (full/empty)
# [INFO] label\photo_normal_227.xml ->
#        ./labels_openclose\photo_normal_227.txt (open/close)
#        ./labels_fullempty\photo_normal_227.txt (full/empty)
# [INFO] label\photo_normal_226.xml ->
#        ./labels_openclose\photo_normal_226.txt (open/close)
#        ./labels_fullempty\photo_normal_226.txt (full/empty)
# [INFO] label\photo_normal_225.xml ->
#        ./labels_openclose\photo_normal_225.txt (open/close)
#        ./labels_fullempty\photo_normal_225.txt (full/empty)
# [INFO] label\photo_normal_224.xml ->
#        ./labels_openclose\photo_normal_224.txt (open/close)
#        ./labels_fullempty\photo_normal_224.txt (full/empty)
# [INFO] label\photo_normal_223.xml ->
#        ./labels_openclose\photo_normal_223.txt (open/close)
#        ./labels_fullempty\photo_normal_223.txt (full/empty)
# [INFO] label\photo_normal_222.xml ->
#        ./labels_openclose\photo_normal_222.txt (open/close)
#        ./labels_fullempty\photo_normal_222.txt (full/empty)
# [INFO] label\photo_normal_221.xml ->
#        ./labels_openclose\photo_normal_221.txt (open/close)
#        ./labels_fullempty\photo_normal_221.txt (full/empty)
# [INFO] label\photo_normal_220.xml ->
#        ./labels_openclose\photo_normal_220.txt (open/close)
#        ./labels_fullempty\photo_normal_220.txt (full/empty)
# [INFO] label\photo_normal_219.xml ->
#        ./labels_openclose\photo_normal_219.txt (open/close)
#        ./labels_fullempty\photo_normal_219.txt (full/empty)
# [INFO] label\photo_normal_218.xml ->
#        ./labels_openclose\photo_normal_218.txt (open/close)
#        ./labels_fullempty\photo_normal_218.txt (full/empty)
# [INFO] label\photo_normal_217.xml ->
#        ./labels_openclose\photo_normal_217.txt (open/close)
#        ./labels_fullempty\photo_normal_217.txt (full/empty)
# [INFO] label\photo_normal_216.xml ->
#        ./labels_openclose\photo_normal_216.txt (open/close)
#        ./labels_fullempty\photo_normal_216.txt (full/empty)
# [INFO] label\photo_normal_215.xml ->
#        ./labels_openclose\photo_normal_215.txt (open/close)
#        ./labels_fullempty\photo_normal_215.txt (full/empty)
# [INFO] label\photo_normal_214.xml ->
#        ./labels_openclose\photo_normal_214.txt (open/close)
#        ./labels_fullempty\photo_normal_214.txt (full/empty)
# [INFO] label\photo_normal_213.xml ->
#        ./labels_openclose\photo_normal_213.txt (open/close)
#        ./labels_fullempty\photo_normal_213.txt (full/empty)
# [INFO] label\photo_normal_212.xml ->
#        ./labels_openclose\photo_normal_212.txt (open/close)
#        ./labels_fullempty\photo_normal_212.txt (full/empty)
# [INFO] label\photo_normal_211.xml ->
#        ./labels_openclose\photo_normal_211.txt (open/close)
#        ./labels_fullempty\photo_normal_211.txt (full/empty)
# [INFO] label\photo_normal_210.xml ->
#        ./labels_openclose\photo_normal_210.txt (open/close)
#        ./labels_fullempty\photo_normal_210.txt (full/empty)
# [INFO] label\photo_normal_209.xml ->
#        ./labels_openclose\photo_normal_209.txt (open/close)
#        ./labels_fullempty\photo_normal_209.txt (full/empty)
# [INFO] label\photo_normal_208.xml ->
#        ./labels_openclose\photo_normal_208.txt (open/close)
#        ./labels_fullempty\photo_normal_208.txt (full/empty)
# [INFO] label\photo_normal_207.xml ->
#        ./labels_openclose\photo_normal_207.txt (open/close)
#        ./labels_fullempty\photo_normal_207.txt (full/empty)
# [INFO] label\photo_normal_307.xml ->
#        ./labels_openclose\photo_normal_307.txt (open/close)
#        ./labels_fullempty\photo_normal_307.txt (full/empty)
